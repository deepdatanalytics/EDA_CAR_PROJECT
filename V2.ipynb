# %%
import numpy as np
import pandas as pd
import json
import re
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %%
pd.set_option('display.max_columns', None)

# %%
def show_nans(df, limit):
    missing = df.isnull().mean()*100
    return missing.loc[lambda x : x > limit]

# %%
def n_sil(x):
    for i in range(0, len(x)):
        if isinstance(x[i], list):
            for a in x[i]:
                if a == "\n":
                    x[i].remove(a)
                elif "\n" in a:
                    x[i].remove(a)
                    b = a.replace("\n", "")
                    x[i].append(b)
        elif isinstance(x[i], str):
            x[i] = x[i].replace("\n", "")

# %%
def Nan_to_list(data, column_name):
    NaN_rows = data[column_name].isnull()
    # Change the type of NaNs from 'float' to (empty) 'list'
    data.loc[NaN_rows, column_name] = data.loc[NaN_rows, column_name].apply(lambda x: [])

# %%
def unique_values(data, column_name):
    unique_vals = set()
    for rows in data[column_name]:
        unique_vals.update(rows)
    return list(unique_vals)

# %%
def fill_most(oto, group_col, col_name):
    for group in list(oto[group_col].unique()):
        try:
            grp_inx = list(oto[oto[group_col] == group][col_name].index)
            oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna(oto[oto[group_col]==group][col_name].mode()[0])
        except Exception as e:
            print("{} 'da {} Error Oldu".format(group, e))
            print("devam ediliyor")

# %%
veri = []
for line in open("scout_car.json", "r"):
    veri.append(json.loads(line))
    
#pd.read_json("scout_car.json", lines = True)

# %%
df = pd.DataFrame(veri)

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.rename(columns={"\nComfort & Convenience\n":"Comfort & Convenience", "\nEntertainment & Media\n":"Entertainment & Media", "\nExtras\n":"Extras", "\nSafety & Security\n":"Safety & Security"}, inplace=True)

# %%
#Verilerin %60ından fazlası null olan sütunlar düşürüldü.
df.drop(["null", 
         "kW", 
         "Electricity consumption", 
         "Last Service Date", 
         "Other Fuel Types", 
         "Availability", 
         "Last Timing Belt Service Date", 
         "Available from", 
         "Inspection new", 
         "Emission Label", 
         "Model Code"], axis=1, inplace=True)

#Tekrarlı veya gereksiz sütunlar düşürüldü.Body=body_type idi.
df.drop(["Body", "Offer Number", "prev_owner", "Non-smoking Vehicle", "Weight", "url", "Full Service", "First Registration"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (15919, 35)

# %%
for i in df.columns:
    Nan_to_list(df, i)

# %%
yeni_list = []
for i in df.columns[9:]:
    yeni_list.append(i)

# %%
yeni_list
# Out:
# ['Previous Owners',
#  'Next Inspection',
#  'Warranty',
#  'Make',
#  'Model',
#  'Body Color',
#  'Paint Type',
#  'Body Color Original',
#  'Upholstery',
#  'Nr. of Doors',
#  'Nr. of Seats',
#  'Gearing Type',
#  'Displacement',
#  'Cylinders',
#  'Drive chain',
#  'Fuel',
#  'Consumption',
#  'CO2 Emission',
#  'Emission Class',
#  'Comfort & Convenience',
#  'Entertainment & Media',
#  'Extras',
#  'Safety & Security',
#  'description',
#  'Gears',
#  'Country version']

# %%
for i in yeni_list:
    n_sil(df[i])

# %%
for i in yeni_list:
    n_sil(df[i])

# %%
df_ilk = df.copy()

# %% [markdown]
# # Previous Owner

# %%
def prev_own(df, clm):   #Prev Owner içinde sadece "0", "1", "2", "3", "4"(prev_owner'da sadece bu değerler olduğu için) olanları alır. 
    for i in range(0, len(df[clm])):
        if type(df[clm][i]) == list:
            for a in df[clm][i]:
                if a in ["0", "1", "2", "3", "4"]:
                    df[clm][i] = a

# %%
prev_own(df, "Previous Owners")

# %%
df["Previous Owners"].value_counts(dropna=False)
# Out:
# 1      8294
# NaN    6640
# 2       778
# 0       188
# 3        17
# 4         2
# Name: Previous Owners, dtype: int64

# %%
df["Previous Owners"][df.Type=="New"] = df["Previous Owners"][df.Type=="New"].fillna("0")

# %% [markdown]
# # Warranty

# %%
def warranty(df, clm):   #Warranty sütunundaki alakasız bilgileri siler.
    for i in range(0, len(df[clm])):
        if type(df[clm][i]) == list:
            df[clm][i] = [x for x in df[clm][i] if x.isnumeric() or "month" in x]
        elif type(df[clm][i]) == str:
            b = []
            b.append(df[clm][i])
            df[clm][i] = [x for x in b if x.isnumeric() or "month" in x]

# %%
warranty(df, "Warranty")

# %% [markdown]
# # Liste Boş Elemanları Silme

# %%
def boslistsil(df, clm):       # Sütundaki listelerin içindeki boşlukları siler.
    for i in range(0, len(df[clm])):
        if type(df[clm][i]) == list:
            df[clm][i] = [x for x in df[clm][i] if len(x)!=0]

# %%
for i in ["CO2 Emission",
         "Emission Class",
         "Type"]:
    boslistsil(df, i)

# %% [markdown]
# # Listeler Stringe

# %%
def liststring(df, col):             #Listeleri stringlere dönüştürür.
    df[col] = [','.join(l) if type(l) == list else l for l in df[col]]
    
def emptytonan(df, col):             #Stringlerdeki boşlukları NaN'a dönüştürür.
    df[col] = [np.NaN if len(l)==0 else l for l in df[col]]

# %%
for i in ["Previous Owners",
          "Warranty", 
          "Model", 
          "Body Color", 
          "Body Color Original", 
          "Upholstery", 
          "Nr. of Doors",
          "Nr. of Seats",
          "Gearing Type",
          "Displacement",
          "Cylinders",
          "Drive chain",
          "CO2 Emission",
          "Emission Class",
          "Paint Type", 
          "Country version", 
          "Gears"]:
    try:
        liststring(df, i)
        emptytonan(df, i)
    except:
        print("{} 'da {} hatası çıktı".format(i, Exception))
# Out:
# Previous Owners 'da <class 'Exception'> hatası çıktı
# Warranty 'da <class 'Exception'> hatası çıktı

# %% [markdown]
# # Fuel

# %%
liststring(df, "Fuel")

# %%
df.Fuel = df.Fuel.str.split("/")

# %%
df.Fuel.value_counts()
# Out:
# [Diesel (Particulate Filter)]                                                                                         4315
# [Super 95]                                                                                                            3338
# [Gasoline]                                                                                                            3175
# [Diesel]                                                                                                              2984
# [Super 95 ,  Regular, Benzine 91]                                                                                      424
#                                                                                                                       ...
# [Super Plus 98 ,  Super E10 95]                                                                                          1
# [Regular, Benzine 91 ,  Super 95 ,  Regular, Benzine E10 91 ,  Super E10 95 ,  Super Plus 98 ,  Super Plus E10 98]       1
# [Super 95 ,  Regular, Benzine 91 ,  Super Plus 98 ,  Regular, Benzine E10 91 ,  Super Plus E10 98 ,  Super E10 95]       1
# [Super 95 ,  Regular, Benzine 91 ,  Super E10 95 ,  Super Plus E10 98 ,  Super Plus 98]                                  1
# [Domestic gas H]                                                                                                         1
# Name: Fuel, Length: 77, dtype: int64

# %%
for i in range(0, len(df.Fuel)):
    df.Fuel[i] = [b.strip() for b in df.Fuel[i]]

# %%
liststring(df, "Fuel")

# %% [markdown]
# # Type

# %%
liststring(df, "Type")

# %%
df.Type = df.Type.str.split("/")

# %%
for i in range(0, len(df.Type)):
    df.Type[i] = [b.strip() for b in df.Type[i]]

# %%
liststring(df, "Type")

# %%
def conversion(df, clm, wtc=[]):
    for i in wtc:
        df[clm][df[clm].str.contains(i, regex=False)] = i

# %%
conversion(df, "Type", wtc=["Used", "Pre-registered", "New", "Employee's car", "Demonstration"])

# %%
df.Type[df.Type == ""] = "Used"

# %% [markdown]
# # Warranty

# %%
fill_most(df, "make_model", "Warranty") #Warranty NANları silindi.
# Out:
# Audi A2 'da index out of bounds Error Oldu
# devam ediliyor

# %%
df.Warranty[df.Warranty.isnull()] = "12 months"

# %% [markdown]
# # body_type

# %%
emptytonan(df, "body_type")

# %%
fill_most(df, "make_model", "body_type")

# %% [markdown]
# # vat

# %%
liststring(df, "vat")

# %%
emptytonan(df, "vat")

# %%
fill_most(df, "make_model", "vat")

# %% [markdown]
# # km

# %%
df.km = df.km.str.strip(" km")

# %%
df.km = df.km.str.replace(",", "")

# %%
df.km[df.km.str[0]== "-"] = np.NaN

# %%
fill_most(df, "make_model", "km")

# %% [markdown]
# # registration

# %%
df.registration[df.registration.str[0]== "-"] = np.NaN

# %%
fill_most(df, "km", "registration")
# Out:
# 0 'da index out of bounds Error Oldu
# devam ediliyor
# 281 'da index out of bounds Error Oldu
# devam ediliyor
# 196 'da index out of bounds Error Oldu
# devam ediliyor
# 141 'da index out of bounds Error Oldu
# devam ediliyor
# 68485 'da index out of bounds Error Oldu
# devam ediliyor
# 81800 'da index out of bounds Error Oldu
# devam ediliyor
# 142 'da index out of bounds Error Oldu
# devam ediliyor
# 39962 'da index out of bounds Error Oldu
# devam ediliyor
# 32084 'da index out of bounds Error Oldu
# devam ediliyor
# 20768 'da index out of bounds Error Oldu
# devam ediliyor
# 34164 'da index out of bounds Error Oldu
# devam ediliyor
# 325 'da index out of bounds Error Oldu
# devam ediliyor
# 89982 'da index out of bounds Error Oldu
# devam ediliyor
# 77 'da index out of bounds Error Oldu
# devam ediliyor
# 89692 'da index out of bounds Error Oldu
# devam ediliyor
# 784 'da index out of bounds Error Oldu
# devam ediliyor
# 497 'da index out of bounds Error Oldu
# devam ediliyor

# %%
df.registration.iloc[df[df.km=="0"].index] = df.registration.iloc[df[df.km=="0"].index].fillna("01/2020")

# %%
fill_most(df, "make_model", "registration")

# %% [markdown]
# # hp

# %%
dfden = df.copy()

# %%
df.hp = df.hp.str.replace(" kW", "")

# %%
df.hp[df.hp.str[0]== "-"] = np.NaN

# %%
fill_most(df, "make_model", "hp")

# %%
df["Previous Owners"][df.Type=="New"] = df["Previous Owners"][df.Type=="New"].fillna("0")

# %%
dfden = df.copy()

# %%
fill_most(dfden, "registration", "Previous Owners")
# Out:
# 11/2019 'da index out of bounds Error Oldu
# devam ediliyor
# 12/2019 'da index out of bounds Error Oldu
# devam ediliyor

# %%
dfden["Previous Owners"] = dfden["Previous Owners"].fillna("1")

# %%
dfden["Previous Owners"].value_counts(dropna=False)
# Out:
# 1    13228
# 0     1894
# 2      778
# 3       17
# 4        2
# Name: Previous Owners, dtype: int64

# %%
df["Previous Owners"].value_counts(dropna=False)
# Out:
# 1      8294
# NaN    5169
# 0      1659
# 2       778
# 3        17
# 4         2
# Name: Previous Owners, dtype: int64

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df.T
# Out:
#                                                                    0      \
# make_model                                                       Audi A1
# short_description            Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                         Sedans
# price                                                              15770
# vat                                                       VAT deductible
# km                                                                 56013
# registration                                                     01/2016
# hp                                                                    66
# Type                                                                Used
# Previous Owners                                                        2
# Next Inspection                            [06/2021, 99 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Body Color Original                                        Mythosschwarz
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,422 cc
# Cylinders                                                              3
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          99 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                 [Alloy wheels, Catalytic Converter, Voice Cont...
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [Sicherheit:,  , Deaktivierung für Beifahrer-A...
# Gears                                                                NaN
# Country version                                                      NaN
#
#                                                                    1      \
# make_model                                                       Audi A1
# short_description                                         1.8 TFSI sport
# body_type                                                         Sedans
# price                                                              14500
# vat                                                     Price negotiable
# km                                                                 80000
# registration                                                     03/2017
# hp                                                                   141
# Type                                                                Used
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                           Red
# Paint Type                                                           NaN
# Body Color Original                                                  NaN
# Upholstery                                                   Cloth, Grey
# Nr. of Doors                                                           3
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,798 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                            Gasoline
# Consumption            [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                         129 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                 [Alloy wheels, Sport seats, Sport suspension, ...
# Safety & Security      [ABS, Central door lock, Central door lock wit...
# description            [Bremsen neu bei 62000 km. , Langstreckenfahrz...
# Gears                                                                  7
# Country version                                                      NaN
#
#                                                                    2      \
# make_model                                                       Audi A1
# short_description      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# body_type                                                         Sedans
# price                                                              14640
# vat                                                       VAT deductible
# km                                                                 83450
# registration                                                     02/2016
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Body Color Original                               mythosschwarz metallic
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           4
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                            NaN
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# CO2 Emission                                          99 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment & Media                           [MP3, On-board computer]
# Extras                                     [Alloy wheels, Voice Control]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 24.64...
# Gears                                                                NaN
# Country version                                                      NaN
#
#                                                                    3      \
# make_model                                                       Audi A1
# short_description                                1.4 TDi Design S tronic
# body_type                                                         Sedans
# price                                                              14500
# vat                                                       VAT deductible
# km                                                                 73000
# registration                                                     08/2016
# hp                                                                    66
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Brown
# Paint Type                                                      Metallic
# Body Color Original                                                  NaN
# Upholstery                                                           NaN
# Nr. of Doors                                                           3
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,422 cc
# Cylinders                                                              3
# Drive chain                                                          NaN
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          99 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air suspension, Armrest, Auxiliary heating, E...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                        [Alloy wheels, Sport seats, Voice Control]
# Safety & Security      [ABS, Alarm system, Central door lock with rem...
# description            [- 1e eigenaar , - Perfecte staat: schade/onge...
# Gears                                                                  6
# Country version                                                      NaN
#
#                                                                    4      \
# make_model                                                       Audi A1
# short_description      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# body_type                                                         Sedans
# price                                                              16790
# vat                                                       VAT deductible
# km                                                                 16200
# registration                                                     05/2016
# hp                                                                    66
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Body Color Original                               Mythosschwarz Metallic
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,422 cc
# Cylinders                                                              3
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                         109 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                 [Alloy wheels, Sport package, Sport suspension...
# Safety & Security      [ABS, Central door lock, Driver-side airbag, E...
# description            [Technik & Sicherheit:, Xenon plus, Klimaautom...
# Gears                                                                NaN
# Country version                                                  Germany
#
#                                                                    5      \
# make_model                                                       Audi A1
# short_description            1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# body_type                                                         Sedans
# price                                                              15090
# vat                                                       VAT deductible
# km                                                                 63668
# registration                                                     02/2016
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         White
# Paint Type                                                      Metallic
# Body Color Original                                                  NaN
# Upholstery                                           Part leather, Black
# Nr. of Doors                                                           4
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                            NaN
# Drive chain                                                          NaN
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.5 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          92 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                 [Alloy wheels, Sport package, Sport seats, Spo...
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [AUTOHERO-RUNDUM-SORGLOS-PAKET,  , Infos:,  1....
# Gears                                                                NaN
# Country version                                                  Germany
#
#                                                                    6      \
# make_model                                                       Audi A1
# short_description          Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# body_type                                                  Station wagon
# price                                                              16422
# vat                                                       VAT deductible
# km                                                                 62111
# registration                                                     03/2016
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         White
# Paint Type                                                      Metallic
# Body Color Original                                       Gletscherweiss
# Upholstery                                           Part leather, Black
# Nr. of Doors                                                           4
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          98 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                 [Alloy wheels, Sport package, Sport seats, Spo...
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [MwSt. ausweisbar, Nettopreis: 13.800,- ¤ zzgl...
# Gears                                                                NaN
# Country version                                                  Germany
#
#                                                                    7      \
# make_model                                                       Audi A1
# short_description                     Sportback 1.4 TDI admired S tronic
# body_type                                                        Compact
# price                                                              14480
# vat                                                       VAT deductible
# km                                                                 14986
# registration                                                     02/2016
# hp                                                                    66
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                           Red
# Paint Type                                                      Metallic
# Body Color Original                                 Misanorot Perleffekt
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,422 cc
# Cylinders                                                            NaN
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.7 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2 Emission                                          97 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Electrical side mi...
# Entertainment & Media                            [CD player, MP3, Radio]
# Extras                                                    [Alloy wheels]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [Ausstattungspakete:,  Ausstattungspaket: admi...
# Gears                                                                  7
# Country version                                                      NaN
#
#                                                                    8      \
# make_model                                                       Audi A1
# short_description                 SPB 1.6 TDI S-tronic Metal plus + Xeno
# body_type                                                         Sedans
# price                                                              16700
# vat                                                       VAT deductible
# km                                                                 57000
# registration                                                     02/2016
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                            [02/2020, 97 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                          Grey
# Paint Type                                                      Metallic
# Body Color Original                                               Grigio
# Upholstery                                                   Cloth, Grey
# Nr. of Doors                                                           5
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          97 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience                  [Air conditioning, Power windows]
# Entertainment & Media                                            [Radio]
# Extras                                                    [Alloy wheels]
# Safety & Security      [ABS, Central door lock, Driver-side airbag, E...
# description            [con soli 57.000 Km. originalissimi, , con tag...
# Gears                                                                  7
# Country version                                                      NaN
#
#                                                                    9      \
# make_model                                                       Audi A1
# short_description                  SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# body_type                                                         Sedans
# price                                                              17990
# vat                                                       VAT deductible
# km                                                                 16103
# registration                                                     06/2017
# hp                                                                    70
# Type                                                                Used
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                        3 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         White
# Paint Type                                                           NaN
# Body Color Original                                                Blanc
# Upholstery                                                           NaN
# Nr. of Doors                                                           5
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                      999 cc
# Cylinders                                                            NaN
# Drive chain                                                          NaN
# Fuel                                                            Gasoline
# Consumption                                                           []
# CO2 Emission                                                         NaN
# Emission Class                                                       NaN
# Comfort & Convenience                                                 []
# Entertainment & Media                                                 []
# Extras                                                                []
# Safety & Security                                                     []
# description            [Clim automatique,Ecran multifonction couleur,...
# Gears                                                                  7
# Country version                                                      NaN
#
#                                                                    10     \
# make_model                                                       Audi A1
# short_description            SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# body_type                                                         Sedans
# price                                                              18500
# vat                                                       VAT deductible
# km                                                                 11300
# registration                                                     05/2018
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Body Color Original                                                 Nero
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           3
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[4 l/100 km (comb)], [4.6 l/100 km (city)], [...
# CO2 Emission                                         105 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Multi-function steering whe...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                                     [Alloy wheels, Shift paddles]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [telefono , xeno , volante multifunzione, clim...
# Gears                                                                  7
# Country version                                                    Italy
#
#                                                                    11     \
# make_model                                                       Audi A1
# short_description      Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|...
# body_type                                                         Sedans
# price                                                              17990
# vat                                                       VAT deductible
# km                                                                 26415
# registration                                                     05/2016
# hp                                                                    92
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                        Silver
# Paint Type                                                     Uni/basic
# Body Color Original                               Florettsilber Metallic
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           4
# Nr. of Seats                                                         NaN
# Gearing Type                                                   Automatic
# Displacement                                                    1,395 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                            Super 95
# Consumption            [[4.9 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                         112 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media  [CD player, Hands-free equipment, On-board com...
# Extras                                       [Alloy wheels, Sport seats]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [Außenausstattung, beheizbare Außenspiegel, Sc...
# Gears                                                                NaN
# Country version                                                      NaN
#
#                                                                    12     \
# make_model                                                       Audi A1
# short_description           Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# body_type                                                         Sedans
# price                                                              18380
# vat                                                       VAT deductible
# km                                                                 31600
# registration                                                     09/2016
# hp                                                                    92
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                           [09/2019, 112 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         White
# Paint Type                                                      Metallic
# Body Color Original                              Gletscherweiss Metallic
# Upholstery                                           Part leather, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,395 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                  Regular,Benzine 91
# Consumption            [[4.9 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                         112 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                 [Alloy wheels, Catalytic Converter, Sport pack...
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [Highlights:, Anschlussgarantie 1 Jahr, max. 6...
# Gears                                                                NaN
# Country version                                                  Germany
#
#                                                                    13     \
# make_model                                                       Audi A1
# short_description            1.4 TFSI 150ch COD Ambition Luxe S tronic 7
# body_type                                                         Sedans
# price                                                              18399
# vat                                                       VAT deductible
# km                                                                 45764
# registration                                                     06/2016
# hp                                                                   112
# Type                                                                Used
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                          Grey
# Paint Type                                                           NaN
# Body Color Original                                           Gris Clair
# Upholstery                                                           NaN
# Nr. of Doors                                                           3
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,395 cc
# Cylinders                                                            NaN
# Drive chain                                                          NaN
# Fuel                                                            Gasoline
# Consumption                                                           []
# CO2 Emission                                                         NaN
# Emission Class                                                       NaN
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media              [Bluetooth, On-board computer, Radio]
# Extras                     [Alloy wheels, Sport seats, Sport suspension]
# Safety & Security      [ABS, Adaptive headlights, Central door lock, ...
# description            [Marque: AUDIModèle: A1Version: 1.4 TFSI 150ch...
# Gears                                                                NaN
# Country version                                                      NaN
#
#                                                                    14     \
# make_model                                                       Audi A1
# short_description      Sportback 1.0 TFSI S-TRonic*Navi*Xenon*APS* Sport
# body_type                                                         Sedans
# price                                                              17990
# vat                                                       VAT deductible
# km                                                                 34914
# registration                                                     10/2016
# hp                                                                    70
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                            [10/2019, 99 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         Black
# Paint Type                                                      Metallic
# Body Color Original                               Mythosschwarz Metallic
# Upholstery                                                  Cloth, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                      999 cc
# Cylinders                                                              3
# Drive chain                                                        front
# Fuel                                                            Super 95
# Consumption            [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                          99 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                     [Alloy wheels, Sport seats, Sport suspension]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [ www.nord-automobile.de, AUDI A1 1.0 TFSI Ult...
# Gears                                                                  7
# Country version                                                  Germany
#
#                                                                    15     \
# make_model                                                       Audi A1
# short_description                      SPB 1.6 TDI 116 CV S tronic Sport
# body_type                                                         Sedans
# price                                                              18700
# vat                                                       VAT deductible
# km                                                                 27000
# registration                                                     04/2016
# hp                                                                    85
# Type                                                      Employee's car
# Previous Owners                                                        1
# Next Inspection                            [04/2020, 97 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                          Grey
# Paint Type                                                      Metallic
# Body Color Original                                               Grigio
# Upholstery                                                   Cloth, Grey
# Nr. of Doors                                                           5
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          97 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment & Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                                                    [Alloy wheels]
# Safety & Security      [ABS, Central door lock, Daytime running light...
# description            [FINANZIAMENTI AGEVOLATI CON FORMULA '' TOP CA...
# Gears                                                                  7
# Country version                                                      NaN
#
#                                                                    16     \
# make_model                                                       Audi A1
# short_description      SPB 1.6 TDI 116 CV Design S-Line SPB 1.6 TDI 1...
# body_type                                                         Sedans
# price                                                              18900
# vat                                                       VAT deductible
# km                                                                  9752
# registration                                                     06/2018
# hp                                                                    85
# Type                                                                Used
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                          Blue
# Paint Type                                                           NaN
# Body Color Original                                              Azzurro
# Upholstery                                                           NaN
# Nr. of Doors                                                           5
# Nr. of Seats                                                           4
# Gearing Type                                                   Automatic
# Displacement                                                    1,598 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                              Diesel
# Consumption            [[3.5 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                          92 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Leather steering wheel, Pow...
# Entertainment & Media                            [CD player, MP3, Radio]
# Extras                        [Alloy wheels, Sport package, Sport seats]
# Safety & Security      [Central door lock, Driver-side airbag, Electr...
# description            [Equipaggiamenti di serie:, Indicatore tempera...
# Gears                                                                  5
# Country version                                                      NaN
#
#                                                                    17     \
# make_model                                                       Audi A1
# short_description             1.4 TDi S tronic*S-Line*Navigatie*Euro 6b*
# body_type                                                         Sedans
# price                                                              18500
# vat                                                       VAT deductible
# km                                                                 28408
# registration                                                     11/2017
# hp                                                                    66
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                                Audi
# Model                                                                 A1
# Body Color                                                         White
# Paint Type                                                           NaN
# Body Color Original                                                  NaN
# Upholstery                                                  Cloth, Black
# ...
# km                                                                  1000
# registration                                                     04/2019
# hp                                                                   165
# Type                                                       Demonstration
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                         White
# Paint Type                                                      Metallic
# Body Color Original                                       perlmutt-weiss
# Upholstery                                           Full leather, Brown
# Nr. of Doors                                                           5
# Nr. of Seats                                                           7
# Gearing Type                                                   Automatic
# Displacement                                                    1,798 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                            Super 95
# Consumption            [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# CO2 Emission                                         153 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                 [Alloy wheels, Catalytic Converter, Sport susp...
# Safety & Security      [ABS, Adaptive Cruise Control, Blind spot moni...
# description            [Ausstattungslinie/ -paket:, Winterpaket., Med...
# Gears                                                                NaN
# Country version                                                      NaN
#
#                                                                    15914  \
# make_model                                                Renault Espace
# short_description                  Blue dCi 200CV EDC Executive 4Control
# body_type                                                            Van
# price                                                              39950
# vat                                                       VAT deductible
# km                                                                    10
# registration                                                     04/2019
# hp                                                                   147
# Type                                                                 New
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       24 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                          Grey
# Paint Type                                                      Metallic
# Body Color Original                                         Grigio scuro
# Upholstery                                                           NaN
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,997 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                         Diesel (Particulate Filter)
# Consumption            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                         139 g CO2/km (comb)
# Emission Class                                                       NaN
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                                      [Alloy wheels, Touch screen]
# Safety & Security      [ABS, Central door lock, Central door lock wit...
# description            [Prezzo escluse spese immatricolazione., Optio...
# Gears                                                                  6
# Country version                                                      NaN
#
#                                                                    15915  \
# make_model                                                Renault Espace
# short_description                    TCe 225 EDC GPF LIM Deluxe Pano,RFK
# body_type                                                            Van
# price                                                              39885
# vat                                                       VAT deductible
# km                                                                  9900
# registration                                                     01/2019
# hp                                                                   165
# Type                                                                Used
# Previous Owners                                                        1
# Next Inspection                           [01/2022, 168 g CO2/km (comb)]
# Warranty                                                       12 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                          Grey
# Paint Type                                                      Metallic
# Body Color Original                                  Stahl-Grau Metallic
# Upholstery                                                         Cloth
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,798 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                         Super 95,Super Plus 98 (Particulate Filter)
# Consumption            [7.4 l/100 km (comb), 9.2 l/100 km (city), 6.3...
# CO2 Emission                                         168 g CO2/km (comb)
# Emission Class                                                       NaN
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras                       [Alloy wheels, Touch screen, Voice Control]
# Safety & Security      [ABS, Adaptive Cruise Control, Blind spot moni...
# description            [Dach: Panorama-Glas-Schiebedach, Lackierung: ...
# Gears                                                                  7
# Country version                                                  Germany
#
#                                                                    15916  \
# make_model                                                Renault Espace
# short_description      Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# body_type                                                            Van
# price                                                              39875
# vat                                                       VAT deductible
# km                                                                    15
# registration                                                     03/2019
# hp                                                                   146
# Type                                                      Pre-registered
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                         White
# Paint Type                                                           NaN
# Body Color Original                                          arktis-weiß
# Upholstery                                           Full leather, Black
# Nr. of Doors                                                           5
# Nr. of Seats                                                           7
# Gearing Type                                                   Automatic
# Displacement                                                    1,997 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                              Diesel
# Consumption            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                         139 g CO2/km (comb)
# Emission Class                                              Euro 6d-TEMP
# Comfort & Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment & Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                                                    [Alloy wheels]
# Safety & Security      [ABS, Adaptive Cruise Control, Blind spot moni...
# description            [Getriebe:,  Automatik, Technik:,  Bordcompute...
# Gears                                                                  6
# Country version                                                  Austria
#
#                                                                    15917  \
# make_model                                                Renault Espace
# short_description      Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# body_type                                                            Van
# price                                                              39700
# vat                                                       VAT deductible
# km                                                                    10
# registration                                                     06/2019
# hp                                                                   147
# Type                                                      Pre-registered
# Previous Owners                                                      NaN
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                          Grey
# Paint Type                                                           NaN
# Body Color Original                                               Grigio
# Upholstery                                                  Part leather
# Nr. of Doors                                                           5
# Nr. of Seats                                                           7
# Gearing Type                                                   Automatic
# Displacement                                                    1,997 cc
# Cylinders                                                              4
# Drive chain                                                        front
# Fuel                                                              Diesel
# Consumption            [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                         139 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media             [Bluetooth, Digital radio, Radio, USB]
# Extras                                      [Alloy wheels, Touch screen]
# Safety & Security      [ABS, Blind spot monitor, Driver-side airbag, ...
# description            [Renault Espace Blue dCi 200CV EDC Business, N...
# Gears                                                                  6
# Country version                                                      NaN
#
#                                                                    15918
# make_model                                                Renault Espace
# short_description            INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
# body_type                                                            Van
# price                                                              40999
# vat                                                       VAT deductible
# km                                                                    10
# registration                                                     01/2019
# hp                                                                   165
# Type                                                       Demonstration
# Previous Owners                                                        1
# Next Inspection                                                       []
# Warranty                                                       12 months
# Make                                                             Renault
# Model                                                             Espace
# Body Color                                                          Grey
# Paint Type                                                      Metallic
# Body Color Original                               Titanium-Grau Metallic
# Upholstery                                           Full leather, Brown
# Nr. of Doors                                                           5
# Nr. of Seats                                                           5
# Gearing Type                                                   Automatic
# Displacement                                                    1,798 cc
# Cylinders                                                              4
# Drive chain                                                          4WD
# Fuel                                                            Super 95
# Consumption            [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# CO2 Emission                                         153 g CO2/km (comb)
# Emission Class                                                    Euro 6
# Comfort & Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment & Media                                              [USB]
# Extras                                      [Alloy wheels, Touch screen]
# Safety & Security      [ABS, Blind spot monitor, Daytime running ligh...
# description            [Sicherheit Airbags:,  , Seitenairbag,  , Fahr...
# Gears                                                                NaN
# Country version                                                  Germany
#
# [35 rows x 15919 columns]

# %% [markdown]
# # NOTLAR

# %%
def boslistsil(df, clm):
    for i in range(0, len(df[clm])):
        if type(df[clm][i]) == list:
            df[clm][i] = [x for x in df[clm][i] if len(x)!=0]
        else:
            df[clm][i] = df[clm][i]

# %%
# TAMAM OLANLAR
    -make_model
    -body_type
    -Gearing Type
    -Previous Owners
    -Warranty
    -Make
    -Model
    -CO2 Emission
    -Emission Class
    -Cylinders

# %%
.str.method,
.contains(),
.extract(),
.to_datetime(),
.get_dummies(),
.add_prefix(),
.sample(),
regex,
.to_numeric(),
.isin(),
.corr().

# %%
s = pd.Series(list('abca'))
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: object

# %%
pd.get_dummies(s)
# Out:
#    a  b  c
# 0  1  0  0
# 1  0  1  0
# 2  0  0  1
# 3  1  0  0

# %%
ee = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})
ee
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
pd.to_datetime(ee)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]

# %%
s3 = pd.Series(['a1', 'b2', 'c3'])
s3
# Out:
# 0    a1
# 1    b2
# 2    c3
# dtype: object

# %%
s3.str.extract(r'([ab])(\d)')
# Out:
#      0    1
# 0    a    1
# 1    b    2
# 2  NaN  NaN

# %%
s1 = pd.Series(['Mouse', 'dog', 'house and parrot', '23', np.NaN])
s1
# Out:
# 0               Mouse
# 1                 dog
# 2    house and parrot
# 3                  23
# 4                 NaN
# dtype: object

# %%
s1.str.contains('og', regex=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4      NaN
# dtype: object

# %%
s2 = pd.Series(["A_Str_Series"])
s2
# Out:
# 0    A_Str_Series
# dtype: object

# %%
s2.str.split("_")
# Out:
# 0    [A, Str, Series]
# dtype: object

# %% [markdown]
# # Stringe Çevirme Bölümü

# %%
a = ["ay", "günes", "misir"]

# %%
", ".join(a)
# Out:
# 'ay, günes, misir'

# %%
def list_string(liste, seperator=' '):
    return seperator.join(liste)

# %%
list_string(a, ", ")
# Out:
# 'ay, günes, misir'

# %%
df['liststring'] = [','.join(map(str, l)) for l in df['Country version']]

# %%
def liststring(dfcol):
    dfcol = [', '.join(l) for l in dfcol]

# %%
df['liststring2'] = [','.join(l) for l in df['Country version']]

# %%
def try_join(l):
    try:
        return ','.join(map(str, l))
    except TypeError:
        return np.nan

# %%
df['liststring'] = [try_join(l) for l in df['Body Color']]

# %%
map(str, ["ay", "günes", "misir"])

# %%
for i in map(str, ["ay", "günes", "misir"]):
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
